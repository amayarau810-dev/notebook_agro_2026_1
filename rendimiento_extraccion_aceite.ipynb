# %% [markdown]
# <a href="https://colab.research.google.com/github/amayarau810-dev/notebook_agro_2026_1/blob/main/rendimiento_extraccion_aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **control de rendimiento en extraccion de aceite**
# ahora se copia este ejercicio es ideal para introducir float, ing y la concentracion de strings
#
# **Planteamiento**:
#
# Una planta procesadora de palma de aceite necesita **calcular el Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos**:
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).
# 3. Solicitar los litros de aceite obtenidos (Tipo float).
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
#
# $$ pa = lt * 0.92 $$
# $$ r =(pa/pr) * 100 $$
#
# **Prueba del programa**:
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de produccion ( Tipo string).
# Solicitar el peso de los racimos en kg ( Tpo float). (pr)
# solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre =  input("ingrese el nombre del lote de produccion: ")
pr = float(input("ingrese el peso de los racimos en kg: "))
lt = float(input("ingrese los litros de aceite obtenidos: "))

# PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
pa= lt * 0.92
r = (pa/pr) * 100

# SALIDA: informar el rendimiento del lote.
print("el rendimiento del lote", nombre, "es del", r, "%")
# Out:
# ingrese el nombre del lote de produccion: El perico
# ingrese el peso de los racimos en kg: 100
# ingrese los litros de aceite obtenidos: 200
# el rendimiento del lote El perico  es del 184.0 %

# %% [markdown]
# Aquí te explico cada línea del código para calcular el rendimiento de extracción de aceite:
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de produccion ( Tipo string).
# # Solicitar el peso de los racimos en kg ( Tpo float). (pr)
# # solicitar los litros de aceite obtenidos (Tipo float). (lt)
# ```
# Estas líneas son comentarios que describen la sección de **entrada** de datos del programa. Indican qué información se solicitará al usuario y el tipo de dato esperado para cada una.
#
# ```python
# nombre =  input("ingrese el nombre del lote de produccion: ")
# ```
# Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` lee lo que el usuario escribe, y ese texto se guarda en la variable `nombre` como una cadena de caracteres (string).
#
# ```python
# pr = float(input("ingrese el peso de los racimos en kg: "))
# ```
# Aquí se le pide al usuario que ingrese el peso de los racimos en kilogramos. El texto ingresado por el usuario se convierte a un número decimal (`float`) usando `float()` y se almacena en la variable `pr` (peso de racimos).
#
# ```python
# lt = float(input("ingrese los litros de aceite obtenidos: "))
# ```
# Similar a la línea anterior, esta solicita los litros de aceite obtenidos. El valor ingresado se convierte a `float` y se guarda en la variable `lt` (litros).
#
# ```python
# # PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Este comentario marca la sección donde se realizan los **cálculos** principales del programa.
#
# ```python
# pa= lt * 0.92
# ```
# Esta línea calcula el peso del aceite (`pa`). Multiplica los litros de aceite obtenidos (`lt`) por la densidad aproximada del aceite (0.92 kg/L). El resultado se guarda en la variable `pa`.
#
# ```python
# r = (pa/pr) * 100
# ```
# Aquí se calcula el rendimiento (`r`). Se divide el peso del aceite (`pa`) entre el peso de los racimos (`pr`) y luego se multiplica por 100 para obtener un porcentaje. El resultado se almacena en la variable `r`.
#
# ```python
# # SALIDA: informar el rendimiento del lote.
# ```
# Este comentario indica la sección de **salida** o resultados del programa.
#
# ```python
# print("el rendimiento del lote", nombre, "es del", r, "%")
# ```
# Finalmente, esta línea muestra el resultado al usuario. Utiliza la función `print()` para construir un mensaje que incluye el nombre del lote (`nombre`) y el rendimiento calculado (`r`), presentado como un porcentaje.
