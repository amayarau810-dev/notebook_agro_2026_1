# %% [markdown]
# <a href="https://colab.research.google.com/github/amayarau810-dev/notebook_agro_2026_1/blob/main/Notebook_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ENTRADA:Entra ancho y alto a la madera en metros
ancho = imput ()
ancho = float (ancho)
alto = imput ("ingresa el ancho de la ventana en metros")
alto = float ()

#PROCESOS: Calcula longitud de la madera (ln) en pies
lm = 2 * (ancho + alto) * 3.25
av = 2 * (ancho * alto)

#SALIDA: Sale la longitud de la madera en pies y el area de vidrio
# en metros cuadrados
print ("la longitud de la madera es" , lm , "pies de longitud")
print ("El area del vidrio es" , av , "metros cuadrados")
# Out:
# la longitud de la madera es 19.5 pies de longitud
# El area del vidrio es 4 metros cuadrados
